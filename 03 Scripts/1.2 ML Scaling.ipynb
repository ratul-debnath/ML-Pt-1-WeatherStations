# %% [markdown]
# # 01 Import Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 02 Import Dataset

# %%
path = r'C:\Users\Ratul\anaconda_projects\Machine Learning'
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Dataset-weather-prediction-dataset-processed.csv'), index_col = False)

# %% [markdown]
# # 03 Scaling

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
# Exclude the date column
df_no_date = df.drop(columns=['DATE'])

# %%
#Select numeric columns for scaling
numeric_cols = df_no_date.select_dtypes(include=['float64', 'int64']).columns

# %%
#Initialize scaler
scaler = StandardScaler()

# %%
#Fit and transform the data
df_scaled = df.copy()
df_scaled[numeric_cols] = scaler.fit_transform(df_no_date[numeric_cols])

# %%
df_scaled.head()
# Out:
#        DATE     MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101 -1.599964           0.660514          -0.02793        0.826097
# 1  19600102 -1.599964           0.244897          -0.02793        0.735760
# 2  19600103 -1.599964           1.076130          -0.02793        1.277781
# 3  19600104 -1.599964          -1.001953          -0.02793        1.458455
# 4  19600105 -1.599964           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# ...

# %%
#Save scaled dataset
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'climate_scaled.csv'), index=False)
